# %%
from pathlib import Path
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

data_path = Path(".") / "drive" / "MyDrive" / "research-projects" / "mr-extraction" / "data"
assert data_path.exists(), data_path

# %%
[_ for _ in data_path.glob("**/*")]
# Out:
# [PosixPath('drive/MyDrive/research-projects/mr-extraction/data/mr-pubmed-abstracts'),
#  PosixPath('drive/MyDrive/research-projects/mr-extraction/data/mr-pubmed-abstracts/data'),
#  PosixPath('drive/MyDrive/research-projects/mr-extraction/data/mr-pubmed-abstracts/data/985_universities.txt'),
#  PosixPath('drive/MyDrive/research-projects/mr-extraction/data/mr-pubmed-abstracts/data/pubmed_new.json'),
#  PosixPath('drive/MyDrive/research-projects/mr-extraction/data/mr-pubmed-abstracts/data/countries.xlsx'),
#  PosixPath('drive/MyDrive/research-projects/mr-extraction/data/mr-pubmed-abstracts/data/pubmed_abstracts.json'),
#  PosixPath('drive/MyDrive/research-projects/mr-extraction/data/mr-pubmed-abstracts/data/pubmed_authors.json'),
#  PosixPath('drive/MyDrive/research-projects/mr-extraction/data/mr-pubmed-abstracts/data/results.RData'),
#  PosixPath('drive/MyDrive/research-projects/mr-extraction/data/mr-pubmed-abstracts/data/pubmed.json'),
# ...

# %% [markdown]
# ---

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, QuantoConfig

# %%
# %%capture
LLAMA_ACCESS_TOKEN = input()
# Out:
# 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

# %%
model_id = "meta-llama/Meta-Llama-3-8B-Instruct"
device = "cuda"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id, token=LLAMA_ACCESS_TOKEN)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map=device,
    token=LLAMA_ACCESS_TOKEN,
)
