# %%
# %load_ext autoreload
# %autoreload 2

import json
from pathlib import Path

import altair as alt
import pandas as pd

from yiutils.project_utils import find_project_root
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
proj_root = find_project_root()
data_dir = proj_root / "data"
assert data_dir.exists(), f"Data directory {data_dir} does not exist."

path_to_pubmed_json = data_dir / "raw" / "mr-pubmed-abstracts" / "data" / "pubmed.json"
assert path_to_pubmed_json.exists(), (
    f"PubMed JSON file {path_to_pubmed_json} does not exist."
)

path_to_pubmed_new_json = (
    data_dir / "raw" / "mr-pubmed-abstracts" / "data" / "pubmed_new.json"
)
assert path_to_pubmed_new_json.exists(), (
    f"PubMed JSON file {path_to_pubmed_new_json} does not exist."
)

# %%
with Path(path_to_pubmed_json).open("r") as f:
    pubmed_json = json.load(f)
    pubmed_df = pd.DataFrame(pubmed_json)

with Path(path_to_pubmed_new_json).open("r") as f:
    pubmed_new_json = json.load(f)
    pubmed_new_df = pd.DataFrame(pubmed_new_json)

# %% [markdown]
# # Glimpse

# %%
pubmed_df.info()
pubmed_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6836 entries, 0 to 6835
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pmid          6836 non-null   object
#  1   ab            6318 non-null   object
#  2   pub_date      6836 non-null   object
#  3   title         6836 non-null   object
#  4   journal_issn  6789 non-null   object
#  5   journal       6836 non-null   object
#  6   author_affil  6714 non-null   object
# dtypes: object(7)
# memory usage: 374.0+ KB
#           pmid                                                 ab    pub_date  \
# 0     38794754  Alcohol consumption significantly impacts dise...  2024-05-25
# 1     38794655  The aim of this study was to assess the causal...  2024-05-25
# 2     38793035  The causal effect and pathways of gut microbio...  2024-05-25
# 3     38790305  Sensorineural hearing loss (SNHL) is a multifa...  2024-05-25
# ...

# %%
pubmed_new_df.info()
pubmed_new_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3290 entries, 0 to 3289
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pmid          3290 non-null   object
#  1   ab            3213 non-null   object
#  2   pub_date      3290 non-null   object
#  3   title         3290 non-null   object
#  4   journal_issn  3212 non-null   object
#  5   journal       3290 non-null   object
#  6   author_affil  3257 non-null   object
# dtypes: object(7)
# memory usage: 180.1+ KB
#           pmid                                                 ab    pub_date  \
# 0     38797633  This Mendelian randomisation (MR) study endeav...  2024-02-14
# 1     38718448  Excess body weight has been recognised as an i...  2023-11-17
# 2     38710707  The causes of temporal fluctuations in adult t...  2023-05-11
# 3     38699308  Blood cell phenotypes are routinely tested in ...  2024-05-03
# ...

# %% [markdown]
# # descriptive stats

# %% [markdown]
# ## num records

# %%
print(len(pubmed_json))
print(len(pubmed_new_json))
# Out:
# 6836
# 3290

# %% [markdown]
# ## num uniq records

# %%
set_id_pubmed_df = set(pubmed_df["pmid"].unique())
set_id_pubmed_new_df = set(pubmed_new_df["pmid"].unique())

print(len(set_id_pubmed_df))
print(len(set_id_pubmed_new_df))
# Out:
# 6836
# 3290

# %% [markdown]
# ## num records overlap

# %%
print(len(set_id_pubmed_df & set_id_pubmed_new_df))
# Out:
# 0

# %% [markdown]
# # num missing values

# %%
cols = ["pmid", "title", "ab", "pub_date"]
for col in cols:
    print(col)
    print(sum(pubmed_df[col].isna()))
    print(sum(pubmed_new_df[col].isna()))
# Out:
# pmid
# 0
# 0
# title
# 0
# 0
# ab
# 518
# 77
# pub_date
# 0
# 0

# %% [markdown]
# # Distribution of the number of abstracts per year

# %%
# Ensure the 'pub_date' column is in datetime format
pubmed_df["pub_date"] = pd.to_datetime(pubmed_df["pub_date"], errors="coerce")

# Extract the year from the 'pub_date' column
pubmed_df["year"] = pubmed_df["pub_date"].dt.year

# Group by year and count the number of records
yearly_counts = pubmed_df.groupby("year").size().reset_index(name="count")

# Create the Altair bar chart
chart = (
    alt.Chart(yearly_counts)
    .mark_bar()
    .encode(
        x=alt.X("year:O", title="Year"),
        y=alt.Y("count:Q", title="Number of Records"),
        tooltip=["year", "count"],
    )
    .properties(
        title="Yearly Sum of Total Number of Records for pubmed_df",
        width=600,
        height=400,
    )
)

chart
# Out:
# alt.Chart(...)

# %%
# Ensure the 'pub_date' column is in datetime format
pubmed_new_df["pub_date"] = pd.to_datetime(pubmed_new_df["pub_date"], errors="coerce")

# Extract the year from the 'pub_date' column
pubmed_new_df["year"] = pubmed_new_df["pub_date"].dt.year

# Group by year and count the number of records
yearly_counts = pubmed_new_df.groupby("year").size().reset_index(name="count")

# Create the Altair bar chart
chart = (
    alt.Chart(yearly_counts)
    .mark_bar()
    .encode(
        x=alt.X("year:O", title="Year"),
        y=alt.Y("count:Q", title="Number of Records"),
        tooltip=["year", "count"],
    )
    .properties(
        title="Yearly Sum of Total Number of Records for pubmed_new_df",
        width=600,
        height=400,
    )
)

chart
# Out:
# alt.Chart(...)
