# %% [markdown]
# Analysis on the preprocessed mr pubmed data set "data / intermediate / mr-pubmed-data / mr-pubmed-data.json"

# %%
# %load_ext autoreload
# %autoreload 2

import json

import altair as alt
import pandas as pd

from yiutils.project_utils import find_project_root
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
proj_root = find_project_root(anchor_file="justfile")
data_dir = proj_root / "data"
assert data_dir.exists(), f"Data directory {data_dir} does not exist."

path_to_processed_mr_pubmed_data = (
    data_dir / "intermediate" / "mr-pubmed-data" / "mr-pubmed-data.json"
)
assert path_to_processed_mr_pubmed_data.exists(), (
    f"Processed MR PubMed data file {path_to_processed_mr_pubmed_data} does not exist."
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 proj_root = find_project_root(anchor_file="justfile")
#       2 data_dir = proj_root / "data"
#       3 assert data_dir.exists(), f"Data directory {data_dir} does not exist."
#
# NameError: name 'find_project_root' is not defined

# %%
with path_to_processed_mr_pubmed_data.open("r") as f:
    mr_pubmed_json = json.load(f)
    mr_pubmed_df = pd.DataFrame(mr_pubmed_json)

# %% [markdown]
# # Glimpse

# %%
mr_pubmed_df.info()
mr_pubmed_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15635 entries, 0 to 15634
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pmid          15635 non-null  object
#  1   ab            15635 non-null  object
#  2   pub_date      15635 non-null  object
#  3   title         15635 non-null  object
#  4   journal_issn  15434 non-null  object
#  5   journal       15635 non-null  object
#  6   author_affil  15473 non-null  object
# dtypes: object(7)
# memory usage: 855.2+ KB
#            pmid                                                 ab  \
# 0      38794754  Alcohol consumption significantly impacts dise...
# 1      38794655  The aim of this study was to assess the causal...
# 2      38793035  The causal effect and pathways of gut microbio...
# 3      38790305  Sensorineural hearing loss (SNHL) is a multifa...
# 4      38789873  Pre-pregnancy obesity was associated with gest...
# ...         ...                                                ...
# 15630  39110833  We aimed to examine the association between hy...
# 15631  39087877  Numerous observational studies link obstructiv...
# 15632  39084694  Ovarian cancer is characterized by late-stage ...
# 15633  39004505  Vitamin D (VitD) affects the risk of multiple ...
# 15634  38889233  Obese adults are often reported to have smalle...
#
#          pub_date                                              title  \
# 0      2024-05-25  Alcohol Exposure and Disease Associations: A M...
# 1      2024-05-25  Exploring the Causal Effects of Mineral Metabo...
# 2      2024-05-25  The Causal Effect of Gut Microbiota and Plasma...
# 3      2024-05-25  Mendelian Randomization Reveals: Triglycerides...
# 4      2024-02-08  Phenome-Wide Investigation of the Causal Assoc...
# ...           ...                                                ...
# 15630  2024-04-01  Hypnotic use and the risk of cardiovascular di...
# 15631  2024-04-16  Novel susceptibility genes and biomarkers for ...
# 15632  2024-08-01  Large-scale analysis to identify risk factors ...
# 15633  2024-04-16  Vitamin D affects the risk of disease activity...
# 15634  2024-03-01  Childhood adiposity underlies numerous adult b...
#
#       journal_issn                                            journal  \
# 0        2072-6643                                          Nutrients
# 1        2072-6643                                          Nutrients
# 2        2075-4426                   Journal of personalized medicine
# 3        2306-5354                Bioengineering (Basel, Switzerland)
# 4        1933-7205      Reproductive sciences (Thousand Oaks, Calif.)
# ...            ...                                                ...
# 15630    2047-4881          European journal of preventive cardiology
# 15631    1550-9109                                              Sleep
# 15632    1525-1438  International journal of gynecological cancer ...
# 15633    1468-330X  Journal of neurology, neurosurgery, and psychi...
# 15634    1460-2156                     Brain : a journal of neurology
#
#                                             author_affil
# 0      Key Laboratory of Environmental Stress and Chr...
# 1      Department of Radiation Medicine, Guangdong Pr...
# 2      Department of Thoracic Surgery, Xiangya Hospit...
# 3      ENT Institute and Department of Otorhinolaryng...
# 4      Xuanwu Hospital, Capital Medical University, B...
# ...                                                  ...
# 15630  Department of Cardiology, State Key Laboratory...
# 15631  Department of Geriatric Neurology, Nanjing Bra...
# 15632  Australian Centre for Precision Health, Unit o...
# 15633  Division of Neuroscience, IRCCS San Raffaele S...
# 15634  Medical Research Council Unit for Lifelong Hea...
#
# [15635 rows x 7 columns]

# %% [markdown]
# # descriptive stats

# %% [markdown]
# ## uniq ids

# %%
uniq_id = set(mr_pubmed_df["pmid"].unique())

print(len(uniq_id))
# Out:
# 15635

# %%
duplicated_pmids = mr_pubmed_df[
    mr_pubmed_df["pmid"].duplicated(keep=False)
].sort_values("pmid")
duplicated_pmids
# Out:
# Empty DataFrame
# Columns: [pmid, ab, pub_date, title, journal_issn, journal, author_affil]
# Index: []

# %% [markdown]
# # num missing values

# %%
cols = ["pmid", "title", "ab", "pub_date"]
for col in cols:
    print(col)
    print(sum(mr_pubmed_df[col].isna()))
# Out:
# pmid
# 0
# title
# 0
# ab
# 0
# pub_date
# 0

# %% [markdown]
# # Distribution of the number of abstracts per year

# %%
# Ensure the 'pub_date' column is in datetime format
mr_pubmed_df["pub_date"] = pd.to_datetime(mr_pubmed_df["pub_date"], errors="coerce")

# Extract the year from the 'pub_date' column
mr_pubmed_df["year"] = mr_pubmed_df["pub_date"].dt.year

# Group by year and count the number of records
yearly_counts = mr_pubmed_df.groupby("year").size().reset_index(name="count")

# Create the Altair bar chart
chart = (
    alt.Chart(yearly_counts)
    .mark_bar()
    .encode(
        x=alt.X("year:O", title="Year"),
        y=alt.Y("count:Q", title="Number of Records"),
        tooltip=["year", "count"],
    )
    .properties(
        title="Yearly Sum of Total Number of Records for mr_pubmed_df",
        width=600,
        height=400,
    )
)

chart
# Out:
# alt.Chart(...)
